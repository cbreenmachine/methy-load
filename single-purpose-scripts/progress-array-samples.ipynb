# %%
library(tidyverse)
# Out:
# ── Attaching packages ────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ───────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df <- read_tsv("../data/meta/ADRC-samplesheet-cleaned.tsv")
# Out:
# Rows: 84 Columns: 7
#
# ── Column specification ───────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): MSA4_ID, COHORT, SEX, ADRC_ID
# dbl (3): Beadchip_ID, AGE, ALISCH_ID
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
df
# Out:
#    Beadchip_ID  MSA4_ID COHORT  SEX AGE ALISCH_ID ADRC_ID
# 1  201516250033 R01C02  CONTROL M   66  127       adrc00081
# 2  201516250015 R01C03  CONTROL F   68  108       adrc00038
# 3  201516250028 R01C04  CONTROL F   77  132       adrc00265
# 4  201516240024 R01C05  CONTROL F   74  124       adrc00006
# 5  201516240057 R01C06  AD      F   77  125       adrc00274
# 6  201516240023 R01C07  CONTROL M   72  131       adrc00277
# 7  201516240028 R01C08  AD      M   80  126       adrc00001
# 8  201516260003 R01C10  CONTROL F   77  138       adrc00286
# 9  201516260009 R01C11  AD      M   67  165       adrc00593
# 10 201516260001 R01C12  AD      F   76  101       adrc00124
# 11 201516250024 R02C01  CONTROL F   81  143       adrc00246
# 12 201516250015 R02C03  CONTROL F   67  182       adrc00329
# 13 201516250028 R02C04  CONTROL M   74  183       adrc00334
# 14 201516240024 R02C05  AD      F   84  167       adrc00455
# 15 201516240057 R02C06  AD      F   74  150       adrc00823
# 16 201516240023 R02C07  AD      M   75  154       adrc00785
# 17 201516240028 R02C08  AD      F   65  166       adrc00354
# 18 201516240029 R02C09  AD      F   64  159       adrc00655
# 19 201516260009 R02C11  AD      M   79  180       adrc00322
# 20 201516260001 R02C12  AD      M   79  128       adrc00150
# 21 201516250024 R03C01  AD      F   66  148       adrc00742
# 22 201516250033 R03C02  CONTROL M   69  114       adrc00200
# 23 201516250028 R03C04  CONTROL M   82  134       adrc00316
# 24 201516240024 R03C05  AD      F   70  155       adrc00778
# 25 201516240057 R03C06  AD      F   69  147       adrc00750
# 26 201516240023 R03C07  AD      F   89  121       adrc00009
# 27 201516240028 R03C08  CONTROL F   77  142       adrc00247
# 28 201516240029 R03C09  AD      M   78  164       adrc00547
# 29 201516260003 R03C10  CONTROL M   84  141       adrc00249
# 30 201516260001 R03C12  AD      M   76  119       adrc00099
# ⋮  ⋮            ⋮       ⋮       ⋮   ⋮   ⋮         ⋮
# 55 201516250028 R06C04  AD      F   79  186       adrc00427
# 56 201516240024 R06C05  CONTROL F   69  188       adrc00339
# 57 201516240023 R06C07  CONTROL F   72  144       adrc00237
# 58 201516240028 R06C08  AD      F   69  111       adrc00123
# 59 201516240029 R06C09  AD      M   70  100       adrc00119
# 60 201516260003 R06C10  AD      M   69  169       adrc00488
# 61 201516260009 R06C11  CONTROL F   72  135       adrc00254
# 62 201516260001 R06C12  CONTROL M   76  137       adrc00291
# 63 201516250024 R07C01  AD      M   72  158       adrc00658
# 64 201516250033 R07C02  AD      F   69  156       adrc00678
# 65 201516250015 R07C03  CONTROL F   80  136       adrc00315
# 66 201516250028 R07C04  AD      M   62  184       adrc00407
# 67 201516240024 R07C05  CONTROL M   66  176       adrc00379
# 68 201516240057 R07C06  AD      M   70  170       adrc00505
# 69 201516240028 R07C08  AD      F   83  145       adrc00768
# 70 201516240029 R07C09  CONTROL M   78  129       adrc00077
# 71 201516260003 R07C10  AD      M   79  106       adrc00066
# 72 201516260009 R07C11  CONTROL M   71  113       adrc00115
# 73 201516260001 R07C12  CONTROL M   84  118       adrc00011
# 74 201516250024 R08C01  AD      F   83  116       adrc00107
# 75 201516250033 R08C02  CONTROL F   77  139       adrc00278
# 76 201516250015 R08C03  AD      F   79  161       adrc00473
# 77 201516250028 R08C04  CONTROL M   76  140       adrc00252
# 78 201516240024 R08C05  CONTROL M   75  109       adrc00201
# 79 201516240057 R08C06  AD      F   81  110       adrc00214
# 80 201516240023 R08C07  CONTROL F   77  120       adrc00182
# 81 201516240029 R08C09  CONTROL F   67  112       adrc00032
# 82 201516260003 R08C10  AD      F   70  157       adrc00771
# 83 201516260009 R08C11  AD      M   80  168       adrc00481
# 84 201516260001 R08C12  AD      M   73  153       adrc00684

# %%
list.files("../data/", recursive = TRUE, full=TRUE, pattern = "04-extract/")
# Out:
# character(0)

# %%
extracted <- list.files("../data/", pattern = "^[0-9][0-9][0-9].tsv", recursive = TRUE)

# %%
todo <- as.character(sort(setdiff(df$ALISCH_ID, str_remove(basename(extracted), ".tsv"))))

# %%
exp.df <- read_tsv("../data/meta/experimental-design.tsv", sep = " ")
# Out:
# Error in read_tsv("../data/meta/experimental-design.tsv", sep = " "): unused argument (sep = " ")
# Traceback:

# %%
exp.df
# Out:
#     sample    machine     pool     group     batch
# 1   100    Novaseq2    pool01    group01     batch01
# 2   101    Novaseq2    pool01    group01     batch01
# 3   104    Novaseq2    pool01    group01     batch01
# 4   105    Novaseq2    pool01    group01     batch01
# 5   106    Novaseq2    pool01    group01     batch01
# 6   107    Novaseq2    pool01    group02     batch01
# 7   108    Novaseq2    pool01    group02     batch01
# 8   109    Novaseq2    pool01    group02     batch01
# 9   110    Novaseq2    pool01    group02     batch01
# 10  111    Novaseq2    pool01    group02     batch01
# 11  112    Novaseq2    pool01    group03     batch01
# 12  113    Novaseq2    pool01    group03     batch01
# 13  114    Novaseq2    pool01    group03     batch01
# 14  115    Novaseq2    pool01    group03     batch01
# 15  116    Novaseq2    pool01    group03     batch01
# 16  118    Novaseq2    pool01    group04     batch01
# 17  119    Novaseq2    pool01    group04     batch01
# 18  120    Novaseq2    pool01    group04     batch01
# 19  122    Novaseq2    pool01    group04     batch01
# 20  123    Novaseq2    pool01    group04     batch01
# 21  124    Novaseq2    pool02    group01     batch01
# 22  125    Novaseq2    pool02    group01     batch01
# 23  126    Novaseq2    pool02    group01     batch01
# 24  127    Novaseq2    pool02    group01     batch01
# 25  128    Novaseq2    pool02    group01     batch01
# 26  129    Novaseq2    pool02    group02     batch01
# 27  130    Novaseq2    pool02    group02     batch01
# 28  131    Novaseq2    pool02    group02     batch01
# 29  132    Novaseq2    pool02    group02     batch01
# 30  133    Novaseq2    pool02    group02     batch01
# ⋮   ⋮
# 193 305    Novaseq1    pool10    group03     batch02
# 194 306    Novaseq1    pool10    group03     batch02
# 195 307    Novaseq1    pool10    group03     batch02
# 196 309    Novaseq1    pool10    group03     batch02
# 197 310    Novaseq1    pool10    group03     batch02
# 198 311    Novaseq1    pool10    group04     batch02
# 199 312    Novaseq1    pool10    group04     batch02
# 200 313    Novaseq1    pool10    group04     batch02
# 201 314    Novaseq1    pool10    group04     batch02
# 202 315    Novaseq1    pool10    group04     batch02
# 203 316    Novaseq2    pool11    group01     batch03
# 204 317    Novaseq2    pool11    group01     batch03
# 205 318    Novaseq2    pool11    group01     batch03
# 206 319    Novaseq2    pool11    group01     batch03
# 207 320    Novaseq2    pool11    group01     batch03
# 208 321    Novaseq2    pool11    group02     batch03
# 209 322    Novaseq2    pool11    group02     batch03
# 210 323    Novaseq2    pool11    group02     batch03
# 211 324    Novaseq2    pool11    group02     batch03
# 212 325    Novaseq2    pool11    group02     batch03
# 213 326    Novaseq2    pool11    group03     batch03
# 214 327    Novaseq2    pool11    group03     batch03
# 215 328    Novaseq2    pool11    group03     batch03
# 216 329    Novaseq2    pool11    group03     batch03
# 217 330    Novaseq2    pool11    group03     batch03
# 218 331    Novaseq2    pool11    group04     batch03
# 219 332    Novaseq2    pool11    group04     batch03
# 220 333    Novaseq2    pool11    group04     batch03
# 221 335    Novaseq2    pool11    group04     batch03
# 222 336    Novaseq2    pool11    group04     batch03
