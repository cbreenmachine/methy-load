# %%
library(Gviz)

# %%
from <- 75195108
to <- 75209506


ensGenes <- UcscTrack(genome = "hg38", chromosome = "chr18",
 track = "Ensembl 76", from = from, to = to, trackType = "GeneRegionTrack",
 rstarts = "exonStarts", rends = "exonEnds", gene = "name",
 symbol = "name2", transcript = "name", strand = "strand",
 fill = "#960000", name = "Ensembl Genes")
# Out:
# Error in match.arg(track, sort(c(availTracks, names(availTracks)))): 'arg' should be one of "1000 Genomes Trios", "1000G Ph3 Vars", "Affy GNF1H", "Affy U133", "Affy U95", "affyGnf1h", "affyU133", "affyU95", "All GENCODE V22", "All GENCODE V23", "All GENCODE V24", "All GENCODE V25", "All GENCODE V26", "All GENCODE V27", "All GENCODE V28", "All GENCODE V29", "All GENCODE V31", "All GENCODE V32", "All GENCODE V33", "All GENCODE V34", "All GENCODE V35", "All GENCODE V36", "All GENCODE V37", "All GENCODE V38", "All GENCODE V39", "All SNPs(141)", "All SNPs(142)", "All SNPs(144)", "All SNPs(146)", "All SNPs(147)", "All SNPs(150)", "All SNPs(151)", "Alt Haplotypes", "altSeqLiftOverPsl", "Assembly", "AUGUSTUS", "augustusGene", "bismap", "Bismap", "Blood PBMC Cells", "Blood PBMC Cells 2", "Blood PBMC Cells 3", "Blood PBMC Donor", "Blood PBMC Phase", "Blood PBMC Time", "bloodHaoCellType", "bloodHaoDonor", "bloodHaoL2", "bloodHaoL3", "bloodHaoPhase", "bloodHaoTime", "Cactus 241-way", "cadd", "CA
# ...

# %%
library(TxDb.Hsapiens.UCSC.hg38.knownGene)

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene

# %%
gene_track <- GeneRegionTrack(txdb, chromosome = "chr18", from = from, to = to)

# %%
(name(gene_tack))
# Out:
# Error in name(gene_tack): could not find function "name"
# Traceback:

# %%
plotTracks(gene_tack, from = from, to = to,
           transcriptAnnotation = "symbol")
# Out:
# plot without title
